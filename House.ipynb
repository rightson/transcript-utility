# %%
# %pip install yt_dlp
import yt_dlp

def yt_url_to_audio(source_url, base_name='audio'):
    ydl_opts = {
        'format': 'bestaudio/best',
        # 'outtmpl': '%(title)%.%(ext)s',
        'outtmpl': f'{base_name}.%(ext)s',
        'postprocessors': [{
            'key': 'FFmpegExtractAudio',
            'preferredcodec': 'mp3',
            'preferredquality': '192',
        }],
    }

    with yt_dlp.YoutubeDL(ydl_opts) as ydl:
        ydl.download([source_url])

if __name__ == '__main__':
    source_url = 'https://www.youtube.com/watch?v=iNmKSPHuz1s'
    base_name = '政府打房拳拳到肉'
    yt_url_to_audio(source_url, base_name)
# Out:
# Collecting yt_dlp
#   Downloading yt_dlp-2024.10.7-py3-none-any.whl.metadata (171 kB)
# Collecting brotli (from yt_dlp)
#   Using cached Brotli-1.1.0-cp311-cp311-macosx_10_9_universal2.whl.metadata (5.5 kB)
# Requirement already satisfied: certifi in ./venv/lib/python3.11/site-packages (from yt_dlp) (2023.5.7)
# Collecting mutagen (from yt_dlp)
#   Using cached mutagen-1.47.0-py3-none-any.whl.metadata (1.7 kB)
# Collecting pycryptodomex (from yt_dlp)
#   Downloading pycryptodomex-3.21.0-cp36-abi3-macosx_10_9_universal2.whl.metadata (3.4 kB)
# Collecting requests<3,>=2.32.2 (from yt_dlp)
#   Using cached requests-2.32.3-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: urllib3<3,>=1.26.17 in ./venv/lib/python3.11/site-packages (from yt_dlp) (2.0.2)
# Collecting websockets>=13.0 (from yt_dlp)
#   Downloading websockets-13.1-cp311-cp311-macosx_11_0_arm64.whl.metadata (6.8 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./venv/lib/python3.11/site-packages (from requests<3,>=2.32.2->yt_dlp) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in ./venv/lib/python3.11/site-packages (from requests<3,>=2.32.2->yt_dlp) (3.4)
# Downloading yt_dlp-2024.10.7-py3-none-any.whl (3.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 14.2 MB/s eta 0:00:0031m11.2 MB/s eta 0:00:01
# Using cached requests-2.32.3-py3-none-any.whl (64 kB)
# Downloading websockets-13.1-cp311-cp311-macosx_11_0_arm64.whl (155 kB)
# Using cached Brotli-1.1.0-cp311-cp311-macosx_10_9_universal2.whl (873 kB)
# Using cached mutagen-1.47.0-py3-none-any.whl (194 kB)
# Downloading pycryptodomex-3.21.0-cp36-abi3-macosx_10_9_universal2.whl (2.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 51.5 MB/s eta 0:00:00
# Installing collected packages: brotli, websockets, requests, pycryptodomex, mutagen, yt_dlp
#   Attempting uninstall: requests
#     Found existing installation: requests 2.31.0
#     Uninstalling requests-2.31.0:
#       Successfully uninstalled requests-2.31.0
# Successfully installed brotli-1.1.0 mutagen-1.47.0 pycryptodomex-3.21.0 requests-2.32.3 websockets-13.1 yt_dlp-2024.10.7
# Note: you may need to restart the kernel to use updated packages.
# [youtube] Extracting URL: https://www.youtube.com/watch?v=iNmKSPHuz1s
# [youtube] iNmKSPHuz1s: Downloading webpage
# [youtube] iNmKSPHuz1s: Downloading ios player API JSON
# [youtube] iNmKSPHuz1s: Downloading mweb player API JSON
# [youtube] iNmKSPHuz1s: Downloading player a4d559ec
# [youtube] iNmKSPHuz1s: Downloading m3u8 information
# [info] iNmKSPHuz1s: Downloading 1 format(s): 251
# [download] Destination: audio.webm
# [download] 100% of   19.69MiB in 00:00:00 at 33.23MiB/s
# [ExtractAudio] Destination: audio.mp3
# Deleting original file audio.webm (pass -k to keep)

# %%
import openai
import os
from pydub import AudioSegment
import math

openai.api_key = os.environ.get('OPENAI_API_KEY')

def mp3_to_transcript(audio_file_path = 'audio.mp3', base_name='', chunk_length_ms = 60000):
    if not base_name:
        base_name = os.path.splitext(os.path.basename(audio_file_path))[0]

    audio = AudioSegment.from_mp3(audio_file_path)
    chunks = math.ceil(len(audio) / chunk_length_ms)
    print('chunks:', chunks)
    chunk_files = []

    for i in range(chunks):
        start_time = i * chunk_length_ms
        end_time = start_time + chunk_length_ms
        chunk = audio[start_time:end_time]
        chunk_file_path = f'{base_name}_chunk_{i}.mp3'
        print('Processing chunk', chunk_file_path)
        if not os.path.exists(chunk_file_path):
            print('Exporting', chunk_file_path)
            chunk.export(chunk_file_path, format='mp3')
        else:
            print('Found', chunk_file_path)
        chunk_files.append(chunk_file_path)

    # Step 3: Transcribe each chunk using OpenAI Whisper-1
    def transcribe_audio(file_path):
        with open(file_path, 'rb') as audio_file:
            transcript = openai.Audio.transcribe(
                model="whisper-1",
                file=audio_file,
                response_format="text"
            )
        return transcript

    transcripts = []
    for chunk_file in chunk_files:
        transcript = transcribe_audio(chunk_file)
        print(transcript)
        transcripts.append(transcript)
        os.remove(chunk_file)

    # Combine all transcriptions
    full_transcript = '\n'.join(transcripts)

    # Save the full transcript to a file
    output_file = f"{base_name}.txt"
    with open(output_file, 'w', encoding='utf-8') as f:
        f.write(full_transcript)

    print(f"Full transcript saved to {output_file}")

    # Cleanup: Remove chunk files
    for chunk_file in chunk_files:
        if os.path.exists(chunk_file):
            os.remove(chunk_file)


if __name__ == '__main__':
    mp3_to_transcript('政府打房拳拳到肉.mp3')
# Out:
# chunks: 27
# Processing chunk audio_chunk_0.mp3
# Exporting audio_chunk_0.mp3
# Processing chunk audio_chunk_1.mp3
# Exporting audio_chunk_1.mp3
# Processing chunk audio_chunk_2.mp3
# Exporting audio_chunk_2.mp3
# Processing chunk audio_chunk_3.mp3
# Exporting audio_chunk_3.mp3
# Processing chunk audio_chunk_4.mp3
# Exporting audio_chunk_4.mp3
# Processing chunk audio_chunk_5.mp3
# Exporting audio_chunk_5.mp3
# Processing chunk audio_chunk_6.mp3
# Exporting audio_chunk_6.mp3
# Processing chunk audio_chunk_7.mp3
# Exporting audio_chunk_7.mp3
# Processing chunk audio_chunk_8.mp3
# Exporting audio_chunk_8.mp3
# Processing chunk audio_chunk_9.mp3
# Exporting audio_chunk_9.mp3
# Processing chunk audio_chunk_10.mp3
# Exporting audio_chunk_10.mp3
# Processing chunk audio_chunk_11.mp3
# Exporting audio_chunk_11.mp3
# Processing chunk audio_chunk_12.mp3
# Exporting audio_chunk_12.mp3
# Processing chunk audio_chunk_13.mp3
# Exporting audio_chunk_13.mp3
# Processing chunk audio_chunk_14.mp3
# Exporting audio_chunk_14.mp3
# Processing chunk audio_chunk_15.mp3
# Exporting audio_chunk_15.mp3
# Processing chunk audio_chunk_16.mp3
# Exporting audio_chunk_16.mp3
# Processing chunk audio_chunk_17.mp3
# Exporting audio_chunk_17.mp3
# Processing chunk audio_chunk_18.mp3
# Exporting audio_chunk_18.mp3
# Processing chunk audio_chunk_19.mp3
# Exporting audio_chunk_19.mp3
# Processing chunk audio_chunk_20.mp3
# Exporting audio_chunk_20.mp3
# Processing chunk audio_chunk_21.mp3
# Exporting audio_chunk_21.mp3
# Processing chunk audio_chunk_22.mp3
# Exporting audio_chunk_22.mp3
# Processing chunk audio_chunk_23.mp3
# Exporting audio_chunk_23.mp3
# Processing chunk audio_chunk_24.mp3
# Exporting audio_chunk_24.mp3
# Processing chunk audio_chunk_25.mp3
# Exporting audio_chunk_25.mp3
# Processing chunk audio_chunk_26.mp3
# Exporting audio_chunk_26.mp3
# 律師或者是所有的一個房仲 就全部一個團夥 就進來騙開發商 然後所以銷售之前的話 這件事情就是在台灣 已經開始有出現一屋多賣 這個設定地籍的異動通知 理財型的房貸不能突銷 要設定抵押 不然詐騙集團就會盯上你 不要突銷 要突銷 一定要突銷 在簽約的時候一定要雙待書 在使用公版的買賣契約書 不要用對方自製的 那當然講這個 跟各位的生活有點遠 等一下我們來講近一點的 成屋履約保證 銷售期間過戶等等 硬件證明 因為這一次的這個事件 其實就是硬件證明害 要取消硬件證明 你要到本人到場才承認 不要搞太方便 太方便就被人家隨便搞掉 因為這一次的話 就是利用硬件證明 來興起了整個詐騙 那接下來的話 因為我們常就是建議大家 因為對很多人來講 剛剛靜怡講得很好 每一個人房子 大概有些人就是很多 但是有些人就是唯一
#
# 所以你會去看那個房子的時候 都是你已經想很久 當然因為FOMO的關係 所以FOMO這個 怕錯失的一個關係 所以這波終於進去 可是其實你在做進去之前 你要有很多工作要 功課要做 比如說你要常常去跑預售案場 你要常常去看人家 賣房子的時候那種氣氛 因為你要知道說 你人一到那邊一定會被洗 就像去拍賣會一樣 你本來不想買的到最後都買 對 所以那種氣氛你要常去 然後預售屋的一個詐騙 當然就是網路上面 有些人就會想說 如果我要買預售屋 如果有人開始集中 你就當我的一個分母 這樣子我們一起去買的話 會比較便宜 原則上你去跟 建設公司來交易的話 當然沒有問題 有些人就是 不然我幫你們代辦 對 我一次多買幾戶 你們就算在我這邊 對 這樣子我們大家的價錢 就可以攤得比較低 像這種的話 什麼中間人 講賣方斡旋 這些其實都會是一些 這個當然都是網路 整理出來的一個資料 但是我覺得
#
# 這些都滿重要 什麼零元買房這一定有問題 對 可是我們又覺得 我們用常識來想說 這種事情怎麼可以騙得到人 對 但是事實上就是被騙了 但是太想買房了 人類的貪念跟慾念 對啊 你如果有去看那個孤注一擲 你就知道 就是說你玩手機 玩一玩當初的時候 你也沒有想要賭那麼大 對不對 你就是 對 你就玩一個賺一個小錢 怎麼到最後都請家當產 對 所以我想預售屋的一個 房價這邊的話 其實這邊整理得很好 叫預售 購屋要到銷售中心 代銷要有證書 要蓋公司大小張 現在因為我們的 台灣的一個建商 很多東西比較健全 當然在國外的世界裡面 比如說日本等等 這個就會出一些問題 檢查票去抬頭 網站上面是不是有一屋多賣 現在這一次的一個事情 好像就是花蓮那個案子 對 一屋二賣 一屋好幾賣的一個問題 還有絕對你不能把錢 匯入到私人的帳戶 但是現在就是說 我們萬一有一些建商 萬一真的倒閉怎麼辦 對 你該做的全部都做了 到最後建商倒閉
#
# 那如果以效力最強的話 當初你在簽約的時候 如果有價金返還的一個制度 基本上是第三方金融機構 來去做承作 然後保證費用是建商來負擔 然後交屋前建商無法挪移 你這個錢拿得到 但是其他像不動產開發信託 或工會連帶保證 這個老實講 基本上都不太會有 真的讓你把真正所有的款項 都拿回來 所以要注意 最好是有價金返還這個保護制制 有價金返還 因為它總共有六個方法 我們上次這邊都有教大家 但價金返還這一塊 可能其他專家會幫我補充 那價金返還這一塊的話 效率應該是相對比較強 OK 好 提醒大家了 謝謝永明哥 小心套路 其實套路都很相似 我們要提高警覺 待會來看看 這一波打房沒有打到都更市場 都更的春天真的到了嗎 馬上再回來

# %%
# ChatGPT version:

import yt_dlp
import openai
import os
from pydub import AudioSegment
import math
import json

class YouTubeTranscriber:
    def __init__(self, source_url, output_file=None):
        self.source_url = source_url
        self.output_file = output_file
        self.audio_file_path = None
        self.chunk_files = []
        self.transcripts = []
        self.chunk_length_ms = 60000  # 1 minute chunks
        self.state_file = 'transcription_state.json'
        openai.api_key = os.getenv('OPENAI_API_KEY')

    def download_audio(self):
        ydl_opts = {
            'format': 'bestaudio/best',
            'outtmpl': '%(title)s.%(ext)s',
            'postprocessors': [{
                'key': 'FFmpegExtractAudio',
                'preferredcodec': 'mp3',
                'preferredquality': '192',
            }],
        }
        with yt_dlp.YoutubeDL(ydl_opts) as ydl:
            info_dict = ydl.extract_info(self.source_url, download=True)
            video_title = info_dict.get('title', 'audio')
            self.audio_file_path = f"{video_title}.mp3"
            if not self.output_file:
                self.output_file = f"{video_title}.txt"

    def create_audio_chunks(self):
        if not self.audio_file_path:
            raise ValueError("Audio file path not set. Please download the audio first.")

        audio = AudioSegment.from_mp3(self.audio_file_path)
        chunks = math.ceil(len(audio) / self.chunk_length_ms)
        print('chunks:', chunks)

        for i in range(chunks):
            start_time = i * self.chunk_length_ms
            end_time = start_time + self.chunk_length_ms
            chunk = audio[start_time:end_time]
            chunk_file_path = f'audio_chunk_{i}.mp3'
            print('Processing chunk', chunk_file_path)
            if not os.path.exists(chunk_file_path):
                print('Exporting', chunk_file_path)
                chunk.export(chunk_file_path, format='mp3')
            else:
                print('Found', chunk_file_path)
            self.chunk_files.append(chunk_file_path)

    def transcribe_audio(self, file_path):
        with open(file_path, 'rb') as audio_file:
            transcript = openai.Audio.transcribe(
                model="whisper-1",
                file=audio_file,
                response_format="text"
            )
        return transcript

    def transcribe_chunks(self):
        for chunk_file in self.chunk_files:
            transcript = self.transcribe_audio(chunk_file)
            print(transcript)
            self.transcripts.append(transcript)
            os.remove(chunk_file)
            self.save_state()

    def save_state(self):
        state = {
            'source_url': self.source_url,
            'audio_file_path': self.audio_file_path,
            'chunk_files': self.chunk_files,
            'transcripts': self.transcripts,
            'output_file': self.output_file
        }
        with open(self.state_file, 'w') as f:
            json.dump(state, f)

    def load_state(self):
        if os.path.exists(self.state_file):
            with open(self.state_file, 'r') as f:
                state = json.load(f)
                self.source_url = state['source_url']
                self.audio_file_path = state['audio_file_path']
                self.chunk_files = state['chunk_files']
                self.transcripts = state['transcripts']
                self.output_file = state['output_file']

    def combine_transcripts(self):
        full_transcript = '\n'.join(self.transcripts)
        print(full_transcript)
        with open(self.output_file, 'w') as f:
            f.write(full_transcript)
        return full_transcript

    def run(self):
        self.load_state()
        if not self.audio_file_path:
            self.download_audio()
        if not self.chunk_files:
            self.create_audio_chunks()
        self.transcribe_chunks()
        self.combine_transcripts()
        self.cleanup()

    def cleanup(self):
        if os.path.exists(self.state_file):
            os.remove(self.state_file)
        if os.path.exists(self.audio_file_path):
            os.remove(self.audio_file_path)
        for chunk_file in self.chunk_files:
            if os.path.exists(chunk_file):
                os.remove(chunk_file)

# Usage
transcriber = YouTubeTranscriber(source_url='https://www.youtube.com/watch?v=IyQiaSS0x0A')
transcriber.run()
